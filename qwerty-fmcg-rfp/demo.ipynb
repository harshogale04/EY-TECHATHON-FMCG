# %%
# CELL 1: Imports & Setup
import sys
sys.path.append('.')

from agents.main_agent import MainAgent

print("✅ MainAgent imported")

# %%
# CELL 2: Run full workflow
main = MainAgent(
    catalog_csv="data/products/product_catalog.csv",
    product_prices_csv="data/products/product_catalog.csv",
    test_prices_csv="data/pricing/test_prices.csv",
)
result = main.run_full_workflow()
print("📋 RFP RESPONSE SAVED!")

# %%
# CELL 3: View Results
import json

with open('rfp_response.json', 'r') as f:
    print(json.dumps(json.load(f), indent=2))
